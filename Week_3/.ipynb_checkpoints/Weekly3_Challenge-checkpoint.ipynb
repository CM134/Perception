# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

plt.gray()

# %%
def SAD_slow(left,right):
    difference = 0
    for y in range(left.shape[0]):
        for x in range(left.shape[1]):
            difference = difference + np.abs(left[x,y].astype('float')-right[x,y].astype('float'))                               
    return difference

def SAD(left_img,right_img):
     return np.sum(np.abs(np.subtract(left_img, right_img, dtype=float)))
    
def patch_matching(patch,span):
    patch_width = patch.shape[1]
    dif = np.zeros(span.shape[1]-patch_width)

    for disp in range(span.shape[1]-patch_width):
        # crop image in size of template
        # start from 0-7 end at end-7
        roi = span[:, disp:disp+patch_width]
        dif[disp] = SAD_slow(patch,roi)

    disp_best = np.argmin(dif)
    value_min = dif[disp_best]
    return disp_best

# %%
# import images

img_left = cv2.imread("tsukuba_left.png")
img_left = cv2.cvtColor(img_left, cv2.COLOR_BGR2RGB)
img_gray_left = cv2.cvtColor(img_left, cv2.COLOR_RGB2GRAY)


img_right = cv2.imread("tsukuba_right.png")
img_right = cv2.cvtColor(img_right, cv2.COLOR_BGR2RGB)
img_gray_right = cv2.cvtColor(img_right, cv2.COLOR_RGB2GRAY)

f, (ax_left, ax_right) = plt.subplots(1, 2, figsize=(12,12))
ax_left.imshow(img_gray_left)
ax_right.imshow(img_gray_right)

# %%
patch_size = 15

left = img_gray_left[100:250,100:200]
plt.imshow(left)
right = img_gray_right[100:250,100:200]
disp_mat = np.zeros_like(left)

for y in range(left.shape[1]-patch_size):
    # get span
    span = right[y:y+patch_size,:]
#     plt.imshow(span)
    for x in range(left.shape[0]-patch_size):
            # get the patch
            patch = left[y:y+patch_size,x:x+patch_size]
            disp_mat[x,y] = patch_matching(patch,span)
            
# print(disp_mat)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-eda7195a9691> in <module>
#      13             # get the patch
#      14             patch = left[y:y+patch_size,x:x+patch_size]
# ---> 15             disp_mat[x,y] = patch_matching(patch,span)
#      16
#      17 # print(disp_mat)
#
# <ipython-input-5-734399c5728b> in patch_matching(patch, span)
#      17         # start from 0-7 end at end-7
#      18         roi = span[:, disp:disp+patch_width]
# ---> 19         dif[disp] = SAD_slow(patch,roi)
#      20
#      21     disp_best = np.argmin(dif)
#
# <ipython-input-5-734399c5728b> in SAD_slow(nose_gray_left, nose_gray_right)
#       3     for y in range(nose_gray_left.shape[0]):
#       4         for x in range(nose_gray_left.shape[1]):
# ----> 5             difference = difference + np.abs(nose_gray_left[x,y].astype('float')-nose_gray_right[x,y].astype('float'))
#       6     return difference
#       7
#
# IndexError: index 14 is out of bounds for axis 1 with size 14

# %%
plt.imshow(disp_mat)

# %%
plt.imshow(patch)
